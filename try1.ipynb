# %% [markdown]
# # NUMPY = Numerical Python

# %%
import numpy as np
array1=np.array([1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 5
#       1 import numpy as np
#       3 # Data penjualan dari 3 cabang toko selama 6 bulan (Januari - Juni)
#       4 # Data ini masih berbentuk array 1 Dimensi (18 elemen)
# ----> 5 data_mentah = np.array(
#       6     120, 135, 150, 145, 160, 170,
#       7     110, 100, 105, 115, 120, 130,
#       8     200, 210, 190, 220, 230, 240
#       9 )
#
# TypeError: 'set' object is not callable
